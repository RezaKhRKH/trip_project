# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# دلیل سفر
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     در این قسمت قصد داریم به پیشبینی دلیل سفر کاربران بپردازیم. برخی از کاربران مستربلیط به دلیل کاری و برخی دیگر به دلایل تفریحی به سفر می‌روند. به منظور شخصی‌سازی بیشتر و دقیق‌تر، مستربلیط قصد دارد بداند هر بلیط به چه دلیلی رزرو می‌شود.
#     <br>
#     حال از داده‌هایی که در اختیارمان قرار گرفته است استفاده می کنیم تا تفریحی یا کاری بودن سفر را تشخیص دهیم.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد میکنیم.
# </font>
# </p>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معرفی مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# مجموعه داده آموزشی شامل ۱۰۱۰۱۷ سطر است که در جدول زیر، توضیحات هر ستون آمده است.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |Created|زمان ثبت بلیط|
# |CancelTime|زمانی که مسافر بلیط را کنسل کرده است|
# |DepartureTime|زمان حرکت|
# |BillID|شناسه خرید|
# |TicketID|شناسه بلیط|
# |ReserveStatus|وضعیت پرداخت مشتری|
# |UserID|شناسه کاربری|
# |Male|آیا بلیط متعلق به زن است یا مرد|
# |Price|قیمت بلیط بدون تخفیف|
# |CouponDiscount|تخفیفی که شخص روی بلیط اعمال کرده است|
# |From|مبدا سفر|
# |To|مقصد سفر|
# |Domestic|آیا سفر، داخلی است یا خارجی|
# |VehicleType|جزئیات وسیله نقلیه را مشخص می‌کند|
# |VehicleClass|آیا وسیله نقلیه، فرست‌کلس است یا نه|
# |Vehicle|نوع وسیله نقلیه|
# |HashPassportNumber_p|هش‌شده شماره پاسپورت|
# |HashEmail|هش‌شده ایمیل|
# |BuyerMobile|هش‌شده شماره موبایل|
# |NationalCode|هش‌شده شماره‌ملی|
# |TripReason|دلیل سفر|
# |Cancel|آیا بلیط کنسل شده‌است یا نه|
#
# </font>
# </div>
# </center>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     مجموعه داده آزمایش نیز مانند مجموعه آموزش است با این تفاوت که ستون <code>Cancel</code> که متغیر هدف مسئله است را در خود ندارد. مجموعه داده آزمایش ۴۳۲۹۳ سطر دارد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# خواندن مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#      در ابتدا نیاز است فایل‌های مجموعه‌داده را بخوانیم. از آنجایی که ستون های Created و DepartureTime از جنس زمان هستند پس آنهارا به صورت نمونه ای از کلاس DateTime میخوانیم.
# </font>
# </p>

# %%
train_data = pd.read_csv('../data/train_data.csv',parse_dates=['Created','DepartureTime'])
train_data.head()
# Out:
#                   Created CancelTime       DepartureTime    BillID   TicketID  \
# 0 2022-10-23 09:38:49.110        NaN 2022-11-02 23:59:00  39710203  1091777.0
# 1 2022-08-15 14:51:43.160        NaN 2022-08-18 04:15:00  38689463  1070902.0
# 2 2022-09-20 17:25:27.250        NaN 2022-09-21 11:00:00  39245173  7624237.0
# 3 2022-06-25 11:32:53.980        NaN 2022-06-26 08:30:00  37957585  2867547.0
# 4 2022-06-01 11:30:53.633        NaN 2022-06-02 23:00:00  37584530  7212559.0
#
#    ReserveStatus    UserID   Male      Price  CouponDiscount  ... Domestic  \
# 0              5  122885.0   True  6600000.0         34425.0  ...        1
# 1              5  876925.0   True  9500000.0             0.0  ...        1
# 2              3  916640.0  False  2000000.0             0.0  ...        1
# 3              2       NaN  False    40000.0             0.0  ...        1
# 4              3       NaN   True  1130000.0             0.0  ...        1
#
#                VehicleType  VehicleClass TripReason Vehicle Cancel  \
# 0                      NaN         False       Work   Plane      0
# 1                      NaN         False        Int   Plane      0
# 2                  VIP 2+1          True       Work     Bus      0
# 3          3 ستاره اتوبوسي           NaN        Int   Train      0
# 4  اسکانیا تک صندلی ۳۱نفره          True        Int     Bus      0
#
#   HashPassportNumber_p                                          HashEmail  \
# 0                  NaN  66c7f29e3b92f3b77e20830ac29e7758037a53d2238a5b...
# 1                  NaN  b24634843858a4175d03422aa9e7211ec3b9f3ce4c481c...
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
#
#     BuyerMobile NationalCode
# 0  764974891906    477368495
# 1   27479149496     15987669
# 2  323657282999    667640412
# 3  169459057632    392476186
# 4  408595008421     79497837
#
# [5 rows x 22 columns]

# %%
test_data = pd.read_csv('../data/test_data.csv',parse_dates=['Created','DepartureTime'])
test_data.head()
# Out:
#                   Created               CancelTime       DepartureTime  \
# 0 2022-07-22 12:52:35.293                      NaN 2022-08-03 17:00:00
# 1 2022-05-16 10:55:29.397  2022-05-18 11:35:15.643 2022-05-19 17:00:00
# 2 2022-02-13 16:10:33.870                      NaN 2022-02-15 22:45:00
# 3 2022-05-01 17:56:18.530                      NaN 2022-05-06 14:30:00
# 4 2022-05-19 18:40:48.760                      NaN 2022-05-21 12:30:00
#
#      BillID   TicketID  ReserveStatus    UserID   Male      Price  \
# 0  38372770  7429183.0              3       NaN  False  1220000.0
# 1  37348034  7147402.0              5       NaN   True  2830000.0
# 2  36058084  6817410.0              3       NaN   True  1480000.0
# 3  37140430  7093047.0              3       NaN  False  2450000.0
# 4  37393459  2789874.0              2  135424.0   True  1965500.0
#
#    CouponDiscount  ...      To Domestic  \
# 0             0.0  ...  اصفهان        1
# 1             0.0  ...      قم        1
# 2             0.0  ...  اردبیل        1
# 3             0.0  ...   شیراز        1
# 4             0.0  ...   تهران        1
#
#                              VehicleType VehicleClass Vehicle Cancel  \
# 0               ماهانVIP مانیتوردار کاوه         True     Bus      0
# 1  VIP 2+1  / سیستم تهویه مطبوع / تخت شو         True     Bus      1
# 2                          25 نفره (VIP)         True     Bus      0
# 3                         Scania VIP 2+1         True     Bus      0
# 4                    3 ستاره 6 تخته كوير          NaN   Train      0
#
#    HashPassportNumber_p                                          HashEmail  \
# 0                   NaN  7ec2bc45a1a56014c60beb9e6ae72e748563f270b5961e...
# 1                   NaN  09731a27ab7323fa8a65a5d61a6f6cdf5b127a5d89d1af...
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN  a9b7344fa6dffcd85117f3b4209a379600a66019dbfb57...
#
#     BuyerMobile  NationalCode
# 0  855578545022     752371627
# 1  687891042993     926996211
# 2  515831406373     890191812
# 3  349742111820     941450742
# 4   63387630789     575541645
#
# [5 rows x 21 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در ابتدا ستون هارا بررسی میکنیم.
#     <br>
#     ستون های UserID , HashPassportNumber_p , CancelTime , Hashemail , BuyerMobile و NationalCode مربوط به اطلاعات هر فرد هستند که نیازی به آنها نداریم زیرا دلیل هر سفر به این متغیرها وابسته نیست.
#     <br>
#     ستونا های BillID و TicketID در ظاهر به دردمان نمیخورند ولی میتوانیم تشخیص دهیم که هر خرید(BillID) مربوط به چند بلیط(TicketID) است.
#     <br>
#     ستون های From , To و VehicleType میتوانند مفید باشند ولی همانطور که در زیر مشاهده میشود، مقادیر تنوع خیلی بالایی دارند و در داده های تست میتوانند متفاوت باشند پس آنها را هم حذف میکنیم تا فرآیند یادگیری را مختل نکنند.
# </font>
# </p>

# %%
train_data['From'].value_counts()
# Out:
# From
# تهران      29518
# مشهد       11421
# اصفهان      9473
# شیراز       6332
# یزد         3755
#            ...
# فلورانس        1
# ماسال          1
# ونیز           1
# لیسبون         1
# آلانیا         1
# Name: count, Length: 226, dtype: int64

# %%
train_data['To'].value_counts()
# Out:
# To
# تهران      29686
# مشهد       13242
# اصفهان      6956
# شیراز       4839
# یزد         3657
#            ...
# زوریخ          1
# دهلران         1
# صوفیه          1
# نایروبی        1
# دوربان         1
# Name: count, Length: 307, dtype: int64

# %%
train_data['VehicleType'].value_counts()
# Out:
# VehicleType
# 4 ستاره اتوبوسي صبا                                                           6221
# 3 ستاره 6 تخته پارسي                                                          3021
# 25 نفره (VIP)                                                                 2237
# 4 ستاره 4 تخته غزال                                                           1982
# 4 ستاره اتوبوسي نگين                                                          1824
#                                                                               ...
# SCANIA DORSA VIP 2+1  / مانیتوردار / پذیرایی / اینترنت / سیستم تهویه مطبوع       1
# اتوبوس ویژه                                                                      1
# SCANIA DORSA VIP 2+1  / سیستم تهویه مطبوع                                        1
# مارال وی ای پی ۲۵نفرتخت شو ترمنیال شرق /تپه/                                     1
# سی ای بی درجه یک فول شارژر صندلی صادقی                                           1
# Name: count, Length: 3108, dtype: int64

# %%
uselessCols = ['UserID','From','To','VehicleType','HashPassportNumber_p','HashEmail','BuyerMobile','NationalCode','CancelTime']
train_data = train_data.drop(uselessCols,axis=1)
test_data = test_data.drop(uselessCols,axis=1)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     حال به سراغ مقادیر گمشده (missing values)  میرویم تا آنها را پر کنیم.
# </font>
# </p>

# %%
train_data.isna().sum()
# Out:
# Created               0
# DepartureTime         0
# BillID                0
# TicketID              0
# ReserveStatus         0
# Male                  0
# Price                 0
# CouponDiscount        0
# Domestic              0
# VehicleClass      38450
# TripReason            0
# Vehicle               0
# Cancel                0
# dtype: int64

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     فقط ستون VehicleClass دارای مقدار گمشده (missing value) است.
#     <br>
#     این ستون تا حدودی به ستون Vehicle مرتبط است یعنی هر وسیله نقلیه توزیع کلاس های مربوط به خود را دارد، پس میتوانیم برای پر کردن مقادیر گمشده ستون VehicleClass از مود این مقادیر که مربوط به یک Vehicle مشخص هستند استفاده کنیم.
# </font>
# </p>

# %%
def fill_with_mode(series):
    # Get mode of the current group
    group_mode = series.mode()
    
    # If group has a mode, fill NaN with it
    if not group_mode.empty:
        series_filled = series.fillna(group_mode.iloc[0])
    else:
        # If group has no mode, fill with global mode
        global_mode = train_data['VehicleClass'].mode()
        if not global_mode.empty:
            series_filled = series.fillna(global_mode.iloc[0])
        else:
            # If even global mode is missing, leave as-is (all NaN)
            series_filled = series
    
    return series_filled

# Apply the filling
train_data['VehicleClass'] = train_data.groupby('Vehicle')['VehicleClass'].transform(fill_with_mode)
test_data['VehicleClass'] = test_data.groupby('Vehicle')['VehicleClass'].transform(fill_with_mode)
# Out:
# /tmp/ipykernel_27771/78041988.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   series_filled = series.fillna(group_mode.iloc[0])
# /tmp/ipykernel_27771/78041988.py:12: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   series_filled = series.fillna(global_mode.iloc[0])
# /tmp/ipykernel_27771/78041988.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   series_filled = series.fillna(group_mode.iloc[0])
# /tmp/ipykernel_27771/78041988.py:12: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   series_filled = series.fillna(global_mode.iloc[0])

# %%
test_data.isna().sum()
# Out:
# Created           0
# DepartureTime     0
# BillID            0
# TicketID          0
# ReserveStatus     0
# Male              0
# Price             0
# CouponDiscount    0
# Domestic          0
# VehicleClass      0
# Vehicle           0
# Cancel            0
# dtype: int64

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     از آنجایی که ستون های DepartureTime و Created از نوع زمان هستند پس ویژگی هایی که لازم داریم از آنها استخراج میکنیم:
#     <br>
#     -
#     روز حرکت و ماه حرکت میتوانند تا حدودی مفید باشند.
#     <br>
#     -
#      تعداد روز های باقی مانده تا روز حرکت هنگاه خرید بلیط هم میتواند در دلیل سفر مؤثر باشد.مثلاً انتظار میرود وقتی این فاصله کم است احتمالا مربوط به سفر های کاری است
#     <br>
#     -
#     اینکه تاریخ حرکت در روز های تعطیل  یا در ساعت های خواب بوده است هم میتواند مفید باشد.مثلا سفر هایی که در روز های تعطیل بوده اند احتمالا تفریحی بوده اند همچنین سفر هایی که در تایم های نیمه شب هستند انتظار میرود کاری باشند
#     <br>
#     -
#     همانطور که در ابتدا نیز گفته شد تعداد هر بلیط در هرشناسه خرید میتواند نشان دهد چند نفره بلیط خریداری شده است مثلا با خانواده بوده یا فردی. از این رو این ویژگی هم میتواند بسیار کمک کننده باشد.
# </font>
# </p>

# %%
train_data['DepartureDay'] = train_data['DepartureTime'].dt.day_name()
test_data['DepartureDay'] = test_data['DepartureTime'].dt.day_name()

# %%
train_data['DepartureMonth'] = train_data['DepartureTime'].dt.month
test_data['DepartureMonth'] = test_data['DepartureTime'].dt.month

# %%
train_data['DayBetweenDepartureAndCreate'] = (train_data['DepartureTime'] - train_data['Created']).dt.days
test_data['DayBetweenDepartureAndCreate'] = (test_data['DepartureTime'] - test_data['Created']).dt.days

# %%
def isHoliday(dt):
    if dt.day_name()=='Friday' or dt.day_name()=='Thursday':
        return 1
    m = dt.month
    if m==1 or m==4 or m==5 or m==6:
        return 1
    return 0
train_data['DepartureIsHoliday'] = train_data['DepartureTime'].apply(isHoliday)
test_data['DepartureIsHoliday'] = test_data['DepartureTime'].apply(isHoliday)

# %%
def isSleepTime(dt):
    h = dt.hour
    if h<=8 :
        return 1
    return 0
train_data['DepartureIsSleepTime'] = train_data['DepartureTime'].apply(isSleepTime)
test_data['DepartureIsSleepTime'] = test_data['DepartureTime'].apply(isSleepTime)

# %%
train_data['PopulationPerBill'] = train_data.groupby('BillID')['TicketID'].transform('count')
test_data['PopulationPerBill'] = test_data.groupby('BillID')['TicketID'].transform('count')

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# حال که ستون های مورد نیاز خود را استخراج کردیم میتوانیم آنهایی را که نیاز نداریم پاک کنیم.
# </font>
# </p>

# %%
uselessCols = ['Created','DepartureTime','BillID','TicketID']
train_data = train_data.drop(uselessCols,axis=1)
test_data = test_data.drop(uselessCols,axis=1)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     حال به سراغ عددی کردن ستون های خود میرویم.
#     <br>
#     ستون های Vehicle و DepartureDay از نوع دسته ای اسمی هستند پس آنها را به شیوه One Hot تبدیل به ستون های باینری میکنیم.
# </font>
# </p>

# %%
nominalCols = ['Vehicle','DepartureDay']

# %%
train_dummies = pd.get_dummies(train_data[nominalCols], drop_first=True)
train_data = pd.concat([train_data.drop(nominalCols, axis=1), train_dummies], axis=1)

test_dummies = pd.get_dummies(test_data[nominalCols], drop_first=True)
test_data = pd.concat([test_data.drop(nominalCols, axis=1), test_dummies], axis=1)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     حال به بررسی داده های پرت میپردازیم.
#     <br>
#     ستون های غیرباینری موجود در این دیتا میتوانند داده پرت داشته باشند.مثلا برای ستون  Price طبیعی است که مقدار پرت داشته باشد یعنی جزئی از توزیع داده ها است، زیرا قیمت سفر هایی که مثلا با هواپیما هستند و مسیر های دوری هم دارند اختلاف قیمت زیادی با سفر های با اتوبوس که تکرار بالایی دارند دارد.
#     <br>
#     پس نیازی به حذف مقادیر پرت در این دیتا نیست.
# </font>
# </p>

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create a single figure with subplots
plt.figure(figsize=(15, 8))  # Adjust width & height as needed
cols = ['ReserveStatus','DayBetweenDepartureAndCreate','PopulationPerBill']
sns.boxplot(data=train_data[cols], orient="h")  # Horizontal boxplots
plt.title("Boxplots of Needed Columns") زیر
plt.show()

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     حال ستون های عددی را استانداردسازی میکنیم.
# </font>
# </p>

# %%
train_data.describe()
# Out:
#        ReserveStatus         Price  CouponDiscount       Domestic  \
# count  101017.000000  1.010170e+05    1.010170e+05  101017.000000
# mean        3.158053  3.203236e+06    4.777172e+03       0.992130
# std         1.073276  7.349195e+06    6.127747e+04       0.088363
# min         2.000000 -1.514000e+06   -2.000000e+03       0.000000
# 25%         2.000000  1.075000e+06    0.000000e+00       1.000000
# 50%         3.000000  1.690000e+06    0.000000e+00       1.000000
# 75%         4.000000  3.043500e+06    0.000000e+00       1.000000
# max         5.000000  3.837646e+08    1.443333e+07       1.000000
#
#               Cancel  DepartureMonth  DayBetweenDepartureAndCreate  \
# count  101017.000000   101017.000000                 101017.000000
# mean        0.151618        7.315244                      5.523179
# std         0.358652        2.451756                      8.154106
# min         0.000000        1.000000                      0.000000
# 25%         0.000000        5.000000                      0.000000
# 50%         0.000000        8.000000                      2.000000
# 75%         0.000000        9.000000                      7.000000
# max         1.000000       12.000000                    213.000000
#
#        DepartureIsHoliday  DepartureIsSleepTime  PopulationPerBill
# count       101017.000000         101017.000000      101017.000000
# mean             0.468674              0.173733           2.192512
# std              0.499020              0.378882           2.322876
# min              0.000000              0.000000           1.000000
# 25%              0.000000              0.000000           1.000000
# 50%              0.000000              0.000000           1.000000
# 75%              1.000000              0.000000           2.000000
# max              1.000000              1.000000          32.000000

# %%
from sklearn.preprocessing import StandardScaler

stds = StandardScaler()
cols = ['ReserveStatus','Price','CouponDiscount','DepartureMonth','DayBetweenDepartureAndCreate','PopulationPerBill']

for col in cols:
    train_data[col] =  stds.fit_transform(train_data[[col]])
    test_data[col] =  stds.transform(test_data[[col]])
train_data.describe()
# Out:
#        ReserveStatus         Price  CouponDiscount       Domestic  \
# count   1.010170e+05  1.010170e+05    1.010170e+05  101017.000000
# mean    1.134303e-16 -2.848727e-17    1.403262e-17       0.992130
# std     1.000005e+00  1.000005e+00    1.000005e+00       0.088363
# min    -1.078994e+00 -6.418743e-01   -1.105987e-01       0.000000
# 25%    -1.078994e+00 -2.895891e-01   -7.796007e-02       1.000000
# 50%    -1.472625e-01 -2.059061e-01   -7.796007e-02       1.000000
# 75%     7.844687e-01 -2.173534e-02   -7.796007e-02       1.000000
# max     1.716200e+00  5.178298e+01    2.354638e+02       1.000000
#
#               Cancel  DepartureMonth  DayBetweenDepartureAndCreate  \
# count  101017.000000    1.010170e+05                  1.010170e+05
# mean        0.151618   -5.795928e-17                 -2.599023e-17
# std         0.358652    1.000005e+00                  1.000005e+00
# min         0.000000   -2.575817e+00                 -6.773528e-01
# 25%         0.000000   -9.443254e-01                 -6.773528e-01
# 50%         0.000000    2.792935e-01                 -4.320764e-01
# 75%         0.000000    6.871664e-01                  1.811146e-01
# max         1.000000    1.910785e+00                  2.544459e+01
#
#        DepartureIsHoliday  DepartureIsSleepTime  PopulationPerBill
# count       101017.000000         101017.000000       1.010170e+05
# mean             0.468674              0.173733       2.778388e-17
# std              0.499020              0.378882       1.000005e+00
# min              0.000000              0.000000      -5.133801e-01
# 25%              0.000000              0.000000      -5.133801e-01
# 50%              0.000000              0.000000      -5.133801e-01
# 75%              1.000000              0.000000      -8.287706e-02
# max              1.000000              1.000000       1.283221e+01

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#      حال ستون هدف را هم به عدد تبدیل میکنیم.
# </font>
# </p>

# %%
train_data['TripReason'] = train_data['TripReason'].map({'Int':1,'Work':0})

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     همانطور که در زیر مشاهده میشود همه ی ستون ها میزان وابستگی خوبی با متغیر هدف دارند و نیازی به حذف هیچکدام نیست.
# </font>
# </p>

# %%
train_data.corr()['TripReason']
# Out:
# ReserveStatus                  -0.068531
# Male                           -0.173823
# Price                           0.086220
# CouponDiscount                  0.045919
# Domestic                       -0.057364
# VehicleClass                   -0.046097
# TripReason                      1.000000
# Cancel                          0.016151
# DepartureMonth                 -0.021729
# DayBetweenDepartureAndCreate    0.351098
# DepartureIsHoliday             -0.030976
# DepartureIsSleepTime           -0.045523
# PopulationPerBill               0.416675
# Vehicle_InternationalPlane      0.057364
# Vehicle_Plane                   0.062025
# Vehicle_Train                   0.273828
# DepartureDay_Monday            -0.000596
# DepartureDay_Saturday          -0.036532
# DepartureDay_Sunday            -0.015994
# DepartureDay_Thursday           0.055860
# DepartureDay_Tuesday            0.009414
# DepartureDay_Wednesday          0.023381
# Name: TripReason, dtype: float64

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     داده های تست که جدا هستند.حال نیاز به داده های validation داریم تا عملکرد مدل آموزشی خود را بررسی کنیم.
# </font>
# </p>

# %%
from sklearn.model_selection import train_test_split

x_train,x_val,y_train,y_val = train_test_split(train_data.drop('TripReason',axis=1),
                                                train_data['TripReason'],test_size=.2,
                                                random_state=535, stratify=train_data['TripReason'])

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     حال که داده را پاکسازی کرده  ویژگی‌هایی را به آن افزوده یا از آن حذف کرده‌ایم، وقت آن است که مدل خود را آموزش دهیم.
#     <br>
#  در اینجا از مدل های تجمعی جنگل تصادفی و xgboost استفاده کرده ایم.
# </font>
# </p>

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf =  RandomForestClassifier(n_estimators=300)
model_rf.fit(x_train,y_train)
y_predict_rf = model_rf.predict(x_val)

# %%
import xgboost as xgb

model_xgb = xgb.XGBClassifier(n_estimators=300)
model_xgb.fit(x_train, y_train)
y_predict_xgb = model_xgb.predict(x_val)

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معیار ارزیابی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     معیاری که برای ارزیابی عملکرد مدل انتخاب کرده‌ایم، <code>f1_score</code> است.
#     <br>
#     همچنین از classification_report و confusion_matrix هم برای مدلی که f1_score بالاتری دارد استفاده کرده ایم.
#     </font>
# </p>

# %%
from sklearn.metrics import f1_score, classification_report, confusion_matrix
print("f1 score for RF: ",f1_score( y_val , y_predict_rf ))
print("f1 score for XGB: ",f1_score( y_val , y_predict_xgb ))
# Out:
# f1 score for RF:  0.798405066260115
# f1 score for XGB:  0.7754532775453278

# %%
print(classification_report(y_val, y_predict_rf))

sns.heatmap(confusion_matrix(y_predict_rf, y_val), annot=True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85     11290
#            1       0.84      0.76      0.80      8914
#
#     accuracy                           0.83     20204
#    macro avg       0.83      0.82      0.83     20204
# weighted avg       0.83      0.83      0.83     20204
# <Axes: >

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
#  پیش‌بینی برای داده تست و خروجی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     پس از مهندسی ویژگی و مدلسازی، الگوریتمی داریم که می‌تواند ما را  به متغیر هدف برساند.
#     <br>
#     حال از این مدل برای پیش‌بینی نمونه‌های موجود در داده تست استفاده می کنیم و نتایج را در قالب جدول (<code>dataframe</code>) زیر ارائه می دهیم.
# </font>
# </p>
#
# <div dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |------|---|
# |Tripreason|دلیل سفر (Int/Work)|
#
# </font>
# </div>

# %%
predicted = model_rf.predict(test_data)
predicted = np.where(predicted == 1, 'Int', 'Work')
y_test = pd.DataFrame({'TripReason':predicted})
y_test
# Out:
#       TripReason
# 0            Int
# 1           Work
# 2           Work
# 3           Work
# 4           Work
# ...          ...
# 43288       Work
# 43289        Int
# 43290       Work
# 43291       Work
# 43292        Int
#
# [43293 rows x 1 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# منابع
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     دیتا ها و مسئله های مربوط به این پروژه از وبسایت کوئرا تهیه شده است.
# </font>
# </p>
# <div align=center>
# <a style="line-height:200%;font-family:vazir;color:#0099cc">https://quera.org</a>
# </div>
